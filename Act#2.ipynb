# %%
import control

# %%
num = [10,20]
num = [10,20]
den = [1,15,50,0]

# %%
import control as ctrl
import matplotlib.pyplot as plt

G = ctrl.tf(num, den)

# %%
print (G)

# %%
t, y = ctrl.step_response(G)
plt.plot(t, y)
plt.xlabel("Time (s)")
plt.ylabel("output")
plt.grid()
plt.show()
