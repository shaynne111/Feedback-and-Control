# %%
import control

# %%
num = [10,20]
num = [10,20]
den = [1,15,50,0]

# %%
import control as ctrl
import matplotlib.pyplot as plt

G = ctrl.tf(num, den)

# %%
print (G)
# Out:
# <TransferFunction>: sys[3]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#        10 s + 20
#   -------------------
#   s^3 + 15 s^2 + 50 s

# %%
t, y = ctrl.step_response(G)
plt.plot(t, y)
plt.xlabel("Time (s)")
plt.ylabel("output")
plt.grid()
plt.show()
